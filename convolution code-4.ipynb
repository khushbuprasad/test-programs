# %%
from keras.layers import Conv2D
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %%
from scipy.ndimage.filters import convolve
from scipy.signal import convolve2d
from scipy import misc

# %%
img = misc.ascent()

# %%
img.shape
# Out:
# (512, 512)

# %%
img_tensor = img.reshape((1, 512, 512, 1))

# %%
img_tensor.shape
# Out:
# (1, 512, 512, 1)

# %%
from keras.models import Sequential

# %%
model=Sequential()

# %%
model.add(Conv2D(1, (3,3), strides=(2,1), input_shape=(512, 512, 1)))
model.compile('adam', 'mse')
# Out:
# WARNING:tensorflow:From C:\Users\Puja\.conda\New folder\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
img_pred_tensor = model.predict(img_tensor)

img_pred_tensor.shape
# Out:
# (1, 255, 510, 1)

# %%
img_pred = img_pred_tensor[0, :, :, 0]

# %%
img_pred.shape
# Out:
# (255, 510)

# %%
plt.imshow(img, cmap='gray')
img.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_pred,cmap='gray')
img_pred.shape
# Out:
# (255, 510)

# %%
weights = model.get_weights()

# %%
weights[0]
# Out:
# array([[[[-0.32179728]],
#
#         [[ 0.4005028 ]],
#
#         [[ 0.26855993]]],
#
#
#        [[[-0.35619724]],
#
#         [[ 0.39873224]],
#
#         [[ 0.46326935]]],
#
#
#        [[[-0.0743832 ]],
#
#         [[-0.49436954]],
#
#         [[ 0.55552304]]]], dtype=float32)

# %%
weights[0].shape
# Out:
# (3, 3, 1, 1)

# %%
plt.imshow(weights[0][:, :, 0, 0], cmap='gray')

# %%
weights[0] = np.ones(weights[0].shape)

# %%
model.set_weights(weights)

# %%
img_pred_tensor = model.predict(img_tensor)

# %%
plt.imshow(img_pred, cmap='gray')

# %%
model=Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(512, 512, 1), padding='same'))
model.compile('adam', 'mse')

img_pred_tensor = model.predict(img_tensor)

img_pred_tensor.shape
# Out:
# (1, 512, 512, 1)
